# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahen-Mahindaratne/Algorithms/blob/main/Bubble-Sort%20Algorithm/Bubble_Sort.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def bubble_sort(array):
    n = len(array)
    for i in range(n):
        # Track if a swap was made in this pass
        swapped = False
        for j in range(0, n - i - 1):
            if array[j] > array[j + 1]:
                # Swap if the element found is greater than the next element
                array[j], array[j + 1] = array[j + 1], array[j]
                swapped = True
        # If no two elements were swapped, the array is sorted
        if not swapped:
            break
    return array

if __name__ == '__main__':
    numbers = [4, 10, 6, 14, 2, 1, 8, 5]
    sorted_numbers = bubble_sort(numbers)
    print('Sorted array: ')
    print(sorted_numbers)
# Out:
# Sorted array:
# [1, 2, 4, 5, 6, 8, 10, 14]
